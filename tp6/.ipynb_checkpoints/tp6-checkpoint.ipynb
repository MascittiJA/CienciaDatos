# %%
import os
import xml.etree.ElementTree
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk import bigrams
from nltk.tokenize import wordpunct_tokenize
import string
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import math
#nltk.download()

# %%
# Se escapearon los & en el archivo y se agregaron los tags <DOCS> para poder parsearlo como un xml
inputXML = './data/ap/ap.txt'
e = xml.etree.ElementTree.parse(inputXML).getroot()
docs = {}

for elem in e.getchildren():
    text = elem.find('TEXT').text
    docno = elem.find('DOCNO').text.strip()
    docs[docno] = text

#docs

# %%
def get_wordnet_pos(tag):

    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

# %%
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english') +  list(string.punctuation)
vocabulary = {}
bigrams_map = {}

for docno, text in docs.items():
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        tokens = nltk.word_tokenize(sentence)
        
        for bigram in bigrams(tokens):
            if (bigram[0] not in stop_words) and (bigram[1] not in stop_words):
                bigrams_map.setdefault((bigram[0], bigram[1]), 0)
                bigrams_map.setdefault((bigram[1], bigram[0]), 0)
                bigrams_map[bigram[0],bigram[1]] = bigrams_map[bigram[0],bigram[1]] + 1
                bigrams_map[bigram[1],bigram[0]] = bigrams_map[bigram[1],bigram[0]] + 1
        tags = nltk.pos_tag(tokens)
        for word, tag in tags:
            wornet_pos = get_wordnet_pos(tag)
            if wornet_pos:
                lemma = lemmatizer.lemmatize(word, wornet_pos)
            else:
                lemma = lemmatizer.lemmatize(word)
            if lemma not in stop_words:
                vocabulary.setdefault(lemma, 0)
                vocabulary[lemma] = vocabulary[lemma] + 1

# %%
print("El tamaño del vocabulario es", len(vocabulary))
# Out:
# El tamaño del vocabulario es 41169

# %%
first_500 = list(map(lambda x: x[0], sorted(vocabulary.items(), key=lambda x: x[1], reverse=True)[:500]))
ordered_bigrams = sorted(bigrams_map.items(), key=lambda x: x[1], reverse=True)

for word in first_500:
    for bigram_entry in ordered_bigrams:
        if bigram_entry[0][0] == word:
            print(word, ",", bigram_entry[0][1])
            break
# Out:
# say , officials
# `` , I
# '' , said
# 's , It
# The , ``
# year , last
# would , n't
# I , ``
# percent , 20
# He , said
# million , shares
# n't , ca
# people , million
# one , said
# also , said
# government , 's
# make , sure
# It , ``
# U.S. , District
# In , ``
# two , years
# official , said
# report , said
# last , year
# go , would
# take , place
# But , ``
# A , ``
# time , first
# state , 's
# could , n't
# Bush , 's
# We , ``
# include , would
# new , The
# get , n't
# day , one
# first , time
# tell , n't
# Soviet , Union
# week , last
# New , York
# United , States
# company , 's
# use , drug
# call , 's
# billion , 1
# work , n't
# month , last
# country , 's
# give , would
# come , n't
# today , said
# plan , 's
# president , vice
# police , said
# Thursday , said
# American , people
# three , years
# group , The
# States , United
# since , time
# Tuesday , said
# market , stock
# member , states
# price , bid
# President , Bush
# issue , The
# Monday , said
# Friday , said
# high , school
# force , task
# Wednesday , said
# They , ``
# know , n't
# think , I
# want , n't
# find , n't
# begin , would
# charge , possession
# leader , Soviet
# home , 's
# end , 's
# York , New
# leave , would
# show , air
# hold , would
# case , The
# program , 's
# kill , us
# good , pretty
# help , would
# military , U.S.
# support , 's
# increase , percent
# nation , 's
# House , White
# right , 's
# see , n't
# federal , government
# late , Thursday
# order , court
# many , people
# vote , would
# talk , show
# city , 's
# ask , I
# rate , annual
# expect , I
# back , go
# part , take
# political , parties
# former , The
# way , best
# spokesman , said
# campaign , 's
# party , 's
# court , The
# pay , would
# trade , deficit
# rise , percent
# news , conference
# close , 's
# law , The
# like , would
# Department , Justice
# 10 , years
# move , The
# business , 's
# early , trading
# try , would
# National , The
# West , German
# office , 's
# release , 's
# There , ``
# South , Africa
# return , home
# child , care
# lead , could
# family , 's
# dollar , The
# change , would
# next , year
# offer , tender
# 1 , million
# system , immune
# continue , would
# area , wide
# point , percentage
# still , 's
# large , part
# allow , would
# problem , The
# share , per
# worker , social
# 're , We
# woman , 's
# Dukakis , Michael
# become , would
# Congress , National
# much , across
# four , years
# Reagan , President
# meeting , annual
# money , The
# need , n't
# may , ``
# bill , The
# sale , The
# ... , We
# drug , trafficking
# fire , opened
# number , The
# meet , would
# believe , n't
# five , years
# economic , growth
# cent , higher
# several , months
# accord , peace
# stock , market
# run , would
# agreement , The
# Gorbachev , 's
# ago , years
# receive , would
# death , penalty
# statement , said
# public , made
# look , forward
# control , arms
# tax , income
# election , presidential
# decision , 's
# Washington , In
# John , Paul
# least , At
# night , Monday
# That , 's
# record , high
# world , 's
# administration , Reagan
# head , former
# attack , heart
# job , 's
# Mrs. , ''
# win , n't
# set , aside
# interest , rates
# major , 's
# remain , would
# service , community
# claim , 's
# sell , would
# student , leaders
# low , 's
# If , ``
# Union , Soviet
# condition , serious
# even , though
# later , days
# chief , executive
# agency , news
# seek , would
# another , In
# oil , prices
# mile , half
# name , 's
# Sunday , said
# keep , help
# put , would
# school , high
# open , door
# long , time
# cause , The
# This , ``
# authority , backup
# arrest , warrant
# die , annually
# announce , would
# policy , foreign
# life , 's
# bring , would
# among , support
# Senate , The
# East , Middle
# cost , would
# man , The
# director , executive
# security , national
# 20 , percent
# provide , would
# national , security
# add , would
# face , value
# well , going
# whether , decide
# place , took
# At , least
# hour , half
# decline , 's
# cut , would
# 30 , industrials
# future , 's
# without , ``
# war , civil
# power , 's
# officer , executive
# rule , would
# 1987 , June
# agree , n't
# foreign , aid
# lose , would
# defense , minister
# follow , would
# question , whether
# start , looking
# bank , central
# send , would
# sign , n't
# result , could
# must , We
# She , said
# On , Monday
# And , ``
# demand , 's
# black , first
# attorney , general
# past , two
# trial , 's
# 2 , Aug.
# consider , would
# Democratic , Party
# second , quarter
# contract , The
# Saturday , said
# effort , 's
# base , air
# economy , 's
# April , 8
# industry , 's
# test , results
# might , It
# Inc. , ``
# troop , U.S.
# reporter , said
# six , months
# total , A
# Iraq , 's
# live , hogs
# far , So
# plant , assembly
# big , ``
# Republican , National
# North , Korea
# raise , money
# 15 , percent
# newspaper , said
# carry , life
# thing , one
# around , Temperatures
# America , 's
# Germany , West
# speak , English
# deal , great
# Corp. , Motors
# source , said
# car , 's
# men , two
# 1986 , February
# Party , Communist
# appear , n't
# union , 's
# never , I
# prison , federal
# small , children
# write , helped
# employee , stock
# reach , could
# Committee , Central
# Co. , Motor
# turn , n't
# strike , general
# involve , would
# chairman , vice
# City , York
# action , political
# 1988 , December
# 've , I
# less , likely
# estimate , officials
# budget , deficit
# aid , foreign
# State , Department
# board , 's
# June , 1
# March , 31
# interview , telephone
# general , attorney
# German , West
# committee , The
# concern , expressed
# buy , one
# No , ``
# Ms. , ''
# near , future
# Japan , 's
# recent , years
# file , papers
# Court , Supreme
# study , The
# refuse , would
# require , would
# Police , said
# top , 's
# break , tax
# California , 's
# conference , news
# measure , The
# side , one
# May , since
# executive , chief
# fight , would
# 'm , I
# 1989 , June
# plane , The
# accuse , Critics
# great , deal
# average , Jones
# away , miles
# fell , prices
# gain , percent
# judge , The
# White , House
# Sen. , said
# Jackson , Jesse
# visit , 's
# University , State
# comment , immediate
# proposal , 's
# air , force
# fall , last
# schedule , behind
# 3 , percent
# investigation , 's
# One , ``
# candidate , presidential
# spend , would
# trading , early
# water , drinking
# line , bottom
# presidential , candidate
# July , 1
# wife , 's
# fail , would
# free , elections
# Israel , 's
# whose , name
# stop , n't
# strong , 's
# 12 , years
# earlier , year
# building , office
# vice , president
# capital , 's
# house , 's
# As , ``
# food , prices
# Europe , Eastern
# Some , ``
# note , The
# George , Bush
# damage , serious
# serve , may
# drop , percent
# little , bit
# General , Attorney
# level , high
# term , prison
# information , services
# hospital , spokeswoman
# sentence , death
# form , every
# television , 's
# Minister , Prime
# fund , trust
# minister , prime
# others , But
# operation , sting
# 5 , percent
# When , ``
# soldier , The
# value , market
# San , Francisco
# position , 's
# opposition , parties
# James , A.
# Africa , South
# outside , gathered
# Robert , said
# Air , Force
# already , 've
# product , national
# 100 , million
# decide , whether
# private , economists
# across , much
# victim , The
# Communist , Party
# figure , 's
# enough , money
# mean , would
# human , rights
# protest , The
# Rep. , said
# body , 's
# arm , right
# grow , could
# nearly , two
# play , sand
# London , In
# appeal , would
# stand , trial
# Texas , West
# analyst , said
# town , 's
# An , estimated
# community , service
# drive , 's
# approve , must
# rebel , forces
# shoot , would
# local , governments
# reduce , would
# along , go
# County , Sheriff
# step , toward
# 25 , percent

# %% [markdown]
# ## 2)

# %%
punctuation = list(string.punctuation)
tokens = []
with open('./data/on-the-origin-of-species.txt') as file:  
    data = file.read() 
    tokens = list(filter(lambda x: x not in punctuation, nltk.word_tokenize(data)))
    
len(tokens)
# Out:
# 209609

# %%
words = ['plants', 'instinct', 'for']

def generate_apparitions_vector(word):
    return [i for i, x in enumerate(tokens) if x == word]

std = 50
std_square = std ** 2
twice_std_square = 2 * std_square
denominator = np.sqrt(2 * np.pi) * std

def gaussian(x):
    x_square = x ** 2 
    exp = (-1) * (x_square / twice_std_square) 
    numerator = np.e ** exp
    return numerator / denominator

text_size = len(tokens)
gaussians = {}
for i in range(text_size):
    gaussians[i] = gaussian(i)
    gaussians[-i] = gaussian(-i)
    
def ro_w(t, apparitions):
    sum = 0
    for i in apparitions:
        sum += gaussians[t - i]
    return sum

def plot_apparitions_from(ro_vector):
    a = [ro_vector[i] for i in range(text_size)]
    plt.plot(a)
    plt.show()
    
    
def calcular_autocorrelacion(tau,ro_vector):
    tamanio = text_size - tau

    acum_ro_i = 0
    acum_ro_it = 0
    acum_ro_i_it = 0
    acum_ro_i_2 = 0
    
    for i in range(tamanio):
        ro_i = ro_vector[i]
        ro_it = ro_vector[i+tau]

        acum_ro_i += ro_i
        acum_ro_it += ro_it
        acum_ro_i_it += ro_i * ro_it

        acum_ro_i_2 += ro_i ** 2

    prom_ro_i_it = acum_ro_i_it / tamanio
    prom_ro_i = acum_ro_i / tamanio
    prom_ro_it = acum_ro_it / tamanio
    prom_ro_i_2 = acum_ro_i_2 / tamanio
    square_prom_ro_i = prom_ro_i ** 2
    
    autocorrelacion = (prom_ro_i_it - (prom_ro_i * prom_ro_it)) / (prom_ro_i_2 - square_prom_ro_i)
    return autocorrelacion

def plot_autocorrelation_from(ro_vector):
    rangos = np.arange(0, 10000, 50) #[10, 50, 100, 250, 500, 750, 1000]

    a = [calcular_autocorrelacion(tao,ro_vector) for tao in rangos]
        
    plt.plot(a)
    plt.show()
    
    
def calculate_ro_vector(apparitions):
    ro_vector = [ro_w(i, apparitions) for i in range(text_size)]
    return ro_vector


def graficos(words):
    for word in words:
        apparitions = generate_apparitions_vector(word)

        ro_vector = calculate_ro_vector(apparitions)
        
        plot_apparitions_from(ro_vector)
        plot_autocorrelation_from(ro_vector)

# %%
graficos(words)

# %%
def entropy(word):
    apparitions = generate_apparitions_vector(word)
    
    N = text_size
    P = 64
    longitud_P = N // P
    n = len(apparitions)

    acum = 0
    
    p_w = n / N

    #h_w = H(word, apparitions, P, longitud_P, n)
    print("n, N, P", n, N, P)
    H_w_mean = H_mean_w(n, N, P)
    

    #acum += p_w * (H_w - h_w)

    return acum

def H_mean_w(n, N, P):
    cota = min(n,N/P)
    print("cota:", cota)
    return (-P) * sum(map(lambda m: internal_function(m, n, N, P), [m for m in range(1,cota+1)]))
    
def internal_function(m, n, N, P):
    aux = (m/n) * np.log2(m/n) * marginal_probability(m, n, N, P) 
    return aux
    
    
def H(word, apparitions, P, longitud_P, n):
    ocurrencias = [calcular_particiones(apparitions, word, i, longitud_P) for i in range(P)] 
    acum = 0
    for i in range(P):
        calculo = ocurrencias[i] / n
        if calculo != 0:
            acum += calculo * np.log2(calculo)
    
    return - acum
    

def calcular_particiones(apparitions,word,i,cota):
    return len(list(filter(lambda x: i*cota <= x <= (i+1)*cota, apparitions)))
    


def nCr(n,r):
    n = int(n)
    r = int(r)
    f = math.factorial
    print('n: ', f(n))
    print('r: ', f(r))
    print('n-r: ', f(n-r))
    return f(n) / f(r) / f(n-r)
        
def marginal_probability(m, n, N, P):
    print("m, n, N, P", m, n, N, P)
    return nCr(n,m) / nCr(N,(N/P)) / nCr((N-n),(N/(P-m)))


entropy(words[1])
# Out:
# n, N, P 72 209609 64
# cota: 72
# m, n, N, P 1 72 209609 64
# n:  61234458376886086861524070385274672740778091784697328983823014963978384987221689274204160000000000000000
# r:  1
# n-r:  850478588567862317521167644239926010288584608120796235886430763388588680378079017697280000000000000000
# n:  ...
# r:  ...
# n-r:  ...
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-47-922fb3dc4042> in <module>()
#      60
#      61
# ---> 62 entropy(words[1])
#
# <ipython-input-47-922fb3dc4042> in entropy(word)
#      13     #h_w = H(word, apparitions, P, longitud_P, n)
#      14     print("n, N, P", n, N, P)
# ---> 15     H_w_mean = H_mean_w(n, N, P)
#      16
#      17
#
# <ipython-input-47-922fb3dc4042> in H_mean_w(n, N, P)
#      23     cota = min(n,N/P)
#      24     print("cota:", cota)
# ---> 25     return (-P) * sum(map(lambda m: internal_function(m, n, N, P), [m for m in range(1,cota+1)]))
#      26
#      27 def internal_function(m, n, N, P):
#
# <ipython-input-47-922fb3dc4042> in <lambda>(m)
#      23     cota = min(n,N/P)
#      24     print("cota:", cota)
# ---> 25     return (-P) * sum(map(lambda m: internal_function(m, n, N, P), [m for m in range(1,cota+1)]))
#      26
#      27 def internal_function(m, n, N, P):
#
# <ipython-input-47-922fb3dc4042> in internal_function(m, n, N, P)
#      26
#      27 def internal_function(m, n, N, P):
# ---> 28     aux = (m/n) * np.log2(m/n) * marginal_probability(m, n, N, P)
#      29     return aux
#      30
#
# <ipython-input-47-922fb3dc4042> in marginal_probability(m, n, N, P)
#      57 def marginal_probability(m, n, N, P):
#      58     print("m, n, N, P", m, n, N, P)
# ---> 59     return nCr(n,m) / nCr(N,(N/P)) / nCr((N-n),(N/(P-m)))
#      60
#      61
#
# <ipython-input-47-922fb3dc4042> in nCr(n, r)
#      53     print('r: ', f(r))
#      54     print('n-r: ', f(n-r))
# ---> 55     return f(n) / f(r) / f(n-r)
#      56
#      57 def marginal_probability(m, n, N, P):
#
# OverflowError: integer division result too large for a float

# %%
entropy(words[1])
# Out:
# C:\Users\mguerson\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in log2
# C:\Users\mguerson\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in double_scalars
# nan

# %%
for i in range(900):
    print('Marginal : ', marginal_probability(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-9570afc4c8bf> in <module>()
#       1 for i in range(900):
# ----> 2     print('Marginal : ', marginal_probability(i))
#
# TypeError: marginal_probability() missing 3 required positional arguments: 'n', 'N', and 'P'
